# %%
import geogradev
import geopandas as gpd

# %%
url = r"C:\Users\Mercedes\Downloads\us_states\us_states.shp"

# %%
gdf = gpd.read_file(url)
gdf.head()

# %%
m = geogradev.Map()
m.add_gdf(gdf, zoom_to_layer=False, hover_style={"fillcolor": "red"})
m

# %%
m = geogradev.Map()
url = "https://github.com/opengeos/datasets/releases/download/us/us_states.zip"
m.add_shp(url, zoom_to_layer=False, hover_style={"fillColor": "red"})
m
